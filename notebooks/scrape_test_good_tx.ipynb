# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
#url = 'https://www.goodtherapy.org/therapists/profile/amy-armstrong-20140117'
url = 'https://www.goodtherapy.org/therapists/profile/cole-struhar-20200413'
page = requests.get(url, headers=headers)

print(page)
# Out:
# <Response [200]>

# %%
soup =BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html itemscope="" itemtype="http://schema.org/Thing" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <script>
#    dataLayer = [];
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-NBFNRL9');
#   </script>
#   <script type="text/javascript">
#    window.onerror = function (msg, url, lineNo, columnNo, error) {
#
#                 if(error == null){
#                     error = new Error();
#                     error.stack = "No error stacktrace";
#                 }
#
#                 $.ajax({
#                     type: 'post',
#                     url: '/jserror.php',
# ...

# %%
list(soup.children)
# Out:
# ['HTML',
#  '\n',
#  <html itemscope="" itemtype="http://schema.org/Thing" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#  <script>
#              dataLayer = [];
#          </script>
#  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#          new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#          j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#          'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#          })(window,document,'script','dataLayer','GTM-NBFNRL9');</script>
#  <script type="text/javascript">
#              window.onerror = function (msg, url, lineNo, columnNo, error) {
#
#                  if(error == null){
#                      error = new Error();
#                      error.stack = "No error stacktrace";
#                  }
#
#                  $.ajax({
#                      type: 'post',
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
# ...

# %%
html = list(soup.children)[14]
list(html.children)
# Out:
# ['\n', <div class="profileName">
#  <h1 class="noMargin" id="profileTitle_id">
#  <span itemprop="name">
#  Amy Armstrong
#  </span>
#  </h1>
#  <h2 class="profileCred">LPC</h2>
#  </div>, '\n', <div class="profileVer greenIconDiv marginBottomTwenty marginTopFive">
#  <i class="fa fa-check-circle"></i>
#  <a href="https://www.goodtherapy.org/verified-credentials.html" target="_blank"> Verified</a>
#  </div>, '\n', <div class="profileTE greenIconDiv marginBottomTwenty marginTopFive">
#  <i class="fa fa-check-circle"></i><a href="/learn-about-therapy/issues/workplace-issues" target="_blank" title="Workplace Issues"> Topic Expert</a> </div>, '\n', <div class="clear" id="profileTelehealth"><strong><i class="fa fa-laptop marginRightFive"></i><span>Telehealth Available</span></strong></div>, '\n', <div class="clear" id="profileProf">
# ...

# %%
desc = soup.find_all('div', class_='profileBottomLeft')
desc
# Out:
# [<div class="profileBottomLeft col s12 m12 l8 xl8">
#  <div class="text">
#  <h2>My Approach to Helping</h2>
#  <p>Wouldn't it be nice to wake up in the morning and be excited about your day? Maybe you have some days like that, but if you're looking for a therapist, I suspect you may spend a lot of mornings gripping the blanket and wishing you could just stop worrying for a little while. You want to be able to look forward to things. You want to be able to celebrate accomplishments. You want to be able to accept compliments and finally believe all those good things your friends say to you.
#  <br> <br/>Let's chat about how to make that happen for you! Lots of us struggle with perfectionism, worry, and self-criticism, but it doesn't have to be that way. Take your first step toward getting kicking those negative thoughts by setting up a 15 minute consultation with me.</br></p> </div>
#  <div class="text">
#  <h2>More Info About My Practice</h2>
#  <p class="more_info">
# ...

# %%
info_list = descr[0].find_all('h2')
info_list
# Out:
# [<h2>My Approach to Helping</h2>,
#  <h2>More Info About My Practice</h2>,
#  <h2>Specific Issue(s) I'm Skilled at Helping With</h2>,
#  <h2>My View on the Purpose of Psychotherapy</h2>,
#  <h2>My Blog Posts</h2>,
#  <h2>Audio Message</h2>,
#  <h2>Image Gallery</h2>]

# %%
for h2 in info_list:
    print(h2.get_text())
    print(h2.get('p'))
# Out:
# My Approach to Helping
# None
# More Info About My Practice
# None
# Specific Issue(s) I'm Skilled at Helping With
# None
# My View on the Purpose of Psychotherapy
# None
# My Blog Posts
# None
# Audio Message
# None
# Image Gallery
# None

# %%
all_text = desc[0].find_all('div', class_='text')

for txt in all_text:
    print(txt.children)
    for child in txt.children:
        print(f'CHILD NAME -------------------- {child.name} ------------------')
        print(child)
    
#all_text[0]
# Out:
# ...
# CHILD NAME -------------------- None ------------------
#
#
# CHILD NAME -------------------- h2 ------------------
# <h2>My Approach to Helping</h2>
# CHILD NAME -------------------- None ------------------
#
#
# CHILD NAME -------------------- p ------------------
# <br> <br/>Let's chat about how to make that happen for you! Lots of us struggle with perfectionism, worry, and self-criticism, but it doesn't have to be that way. Take your first step toward getting kicking those negative thoughts by setting up a 15 minute consultation with me.</br></p>
# CHILD NAME -------------------- None ------------------
#
# ...
# CHILD NAME -------------------- None ------------------
#
#
# CHILD NAME -------------------- h2 ------------------
# <h2>More Info About My Practice</h2>
# CHILD NAME -------------------- None ------------------
#
#
# CHILD NAME -------------------- p ------------------
# <p class="more_info">
# ...

# %%
good_stuff = []
for txt in all_text:
    for child in txt.children:
        if(child.name == 'p'):
            good_stuff.append(child.get_text())
            
good_stuff_st = ''.join(good_stuff)
good_stuff_st
# Out:
# "Wouldn't it be nice to wake up in the morning and be excited about your day? Maybe you have some days like that, but if you're looking for a therapist, I suspect you may spend a lot of mornings gripping the blanket and wishing you could just stop worrying for a little while. You want to be able to look forward to things. You want to be able to celebrate accomplishments. You want to be able to accept compliments and finally believe all those good things your friends say to you.\r Let's chat about how to make that happen for you! Lots of us struggle with perfectionism, worry, and self-criticism, but it doesn't have to be that way. Take your first step toward getting kicking those negative thoughts by setting up a 15 minute consultation with me.\nInsurance is accepted, and I am an in-network provider with Beacon, Cigna, Horizon Blue Cross Blue ShieldAnthem, and United Health CareOptum. I accept all major credit cards as well as Venmo. Free parking is available on-site. If you have pani
# ...

# %% [markdown]
# # Functions For GoodTherapy.com

# %%
#def get_page(url):
#    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
#    return requests.get(url, headers=headers)

# %%
def get_soup(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    soup.prettify()
    return soup

# %%
def clean_string(string):
    cleaned = string
    cleaned = cleaned.replace('/','')
    cleaned = cleaned.replace('/n','')
    cleaned = cleaned.replace('\r','')
    
    return cleaned

# %%
def get_good_tx_text(soup):
    desc = soup.find_all('div', class_='profileBottomLeft')
    all_text = desc[0].find_all('div', class_='text')
    good_stuff = []
    for txt in all_text:
        for child in txt.children:
            if(child.name == 'p'):
                good_stuff.append(child.get_text())

    good_stuff_st = ''.join(good_stuff)
    return good_stuff_st

# %%
def get_good_tx_issues(soup)-> list:
    issues_html = soup.find_all('ul', id='issuesData')
    issues_list = list(issues_html[0].children)
    
    
    issues_str = issues_html[0].get_text()
    clean_str = clean_string(issues_str)
    
    return issues_list

# %%
page = requests.get('https://www.goodtherapy.org/therapists/profile/vickie-kulinski-20160324')
soup =BeautifulSoup(page.content, 'html.parser')
new_record = get_good_tx_text(soup)
new_record
# Out:
# "Are you interested in ensuring the success of your relationship, are you struggling with transitions or relationships.. I can help you see patterns in yourself and your life, achieve goals you set forth and generally improve. I tend to be logic based but focused on emotions as well. I work well with both men and women, seniors and LGBT. I want to understand you and your situation. I tend to be direct and honest with feedback. You set the agenda and the pace, we will focus on your goals in therapy and I will help you the best I can to achieve what you set out to achieve.\rYou are in control of sessions, you decide what we focus on and where we go, goals and speed. Usually sessions start with my asking how you are doing and then we may return to previously discussed goals or talk about what is currently happening in your life. I like recommending books and even using movies or TV to make points. Because I tend to be on the casual side, sessions are pretty relaxed and casual.\nReaching
# ...

# %%
issues_html = soup.find_all('ul', id='issuesData')
issues_str = issues_html[0].get_text()
issues_str = issues_str.replace('/','')
issues_str = issues_str.replace('\n','')
clean_string(issues_str)
# Out:
# "Adjusting to Change  Life TransitionsBipolarCodependency  DependencyCommunication ProblemsDepressionEmotional OverwhelmEmptinessFamily of Origin IssuesFamily ProblemsLGBT (Lesbian, Gay, Bisexual, and Transgender) IssuesLife Purpose  Meaning  Inner-GuidanceMood Swings  Mood DisturbanceSelf-CareSelf-CompassionStressWomen's Issues "

# %%
issues_html = soup.find_all('ul', id='issuesData')
for issue in issues_html[0].children:
    print(issue)
# Out:
# <li>Adjusting to Change / Life Transitions</li>
# <li>Bipolar</li>
# <li>Codependency / Dependency</li>
# <li>Communication Problems</li>
# <li>Depression</li>
# <li>Emotional Overwhelm</li>
# <li>Emptiness</li>
# <li>Family of Origin Issues</li>
# <li>Family Problems</li>
# <li>LGBT (Lesbian, Gay, Bisexual, and Transgender) Issues</li>
# <li>Life Purpose / Meaning / Inner-Guidance</li>
# <li>Mood Swings / Mood Disturbance</li>
# <li>Self-Care</li>
# <li>Self-Compassion</li>
# <li>Stress</li>
# <li>Women's Issues</li>

# %%
get_good_tx_issues(soup)
# Out:
# "Adjusting to Change  Life TransitionsBipolarCodependency  DependencyCommunication ProblemsDepressionEmotional OverwhelmEmptinessFamily of Origin IssuesFamily ProblemsLGBT (Lesbian, Gay, Bisexual, and Transgender) IssuesLife Purpose  Meaning  Inner-GuidanceMood Swings  Mood DisturbanceSelf-CareSelf-CompassionStressWomen's Issues "

# %%
soup = get_soup(url = 'https://www.goodtherapy.org/therapists/profile/cole-struhar-20200413')

# %%
get_good_tx_issues(soup)
# Out:
# ['\n',
#  <li>Addictions and Compulsions</li>,
#  <li>Adjusting to Change / Life Transitions</li>,
#  <li>Aging and Geriatric Issues</li>,
#  <li>Anger</li>,
#  <li>Anxiety</li>,
#  <li>Breakup</li>,
#  <li>Cancer</li>,
#  <li>Career Choice</li>,
#  <li>Chronic Illness / Disability</li>,
#  <li>Creative Blocks</li>,
#  <li>Depression</li>,
#  <li>Divorce / Divorce Adjustment</li>,
#  <li>Emotional Intelligence</li>,
#  <li>Emptiness</li>,
#  <li>Fear</li>,
#  <li>First Responders</li>,
#  <li>Forgiveness</li>,
#  <li>Grief, Loss, and Bereavement</li>,
#  <li>Health / Illness / Medical Issues</li>,
#  <li>HIV / AIDS</li>,
#  <li>Individuation</li>,
#  <li>Irritability</li>,
#  <li>Isolation</li>,
#  <li>Jealousy</li>,
#  <li>LGBT (Lesbian, Gay, Bisexual, and Transgender) Issues</li>,
#  <li>Life Purpose / Meaning / Inner-Guidance</li>,
#  <li>Midlife Crisis / Midlife Transition</li>,
#  <li>Multicultural Concerns</li>,
#  <li>Other - Not Listed Here</li>,
#  <li>Perfectionism</li>,
# ...

# %%
get_good_tx_text(soup)
# Out:
# 'We live in a complex world. COVID-19 is a tipping point for many folks. I offer online support for people experiencing despair. Despair is different than depression- something that you intuitively know. Depression is a clinical diagnosis often associated with a chemical imbalance. Despair is a psycho-spiritual imbalance. It is the language of oppression. Despair is hopelessness and a loss of meaning. It is, essentially, the anxiety that comes from an inability to be oneself in a strange (and beautiful) world.\r Despair is not treatable by medication, but it is treatable. Your are not alone. I have committed my private practice to supporting people like you in finding your way out of despair. I use Meaning-Centered therapeutic techniques proven to help people navigate the pain of despair while accessing their true Selves and redesigning their lives.\r I understand if you cannot feel the truth of this from where you are right now, but despair is the call to heal. It is the soul’s dema
# ...
